# %%
import pandas as pd

df = pd.read_csv('customer_shopping_behavior.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_183/2394180532.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('customer_shopping_behavior.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_183/1793760910.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# 1. Dataset Overview
#
# Dataset Customer Shopping Behavior chứa 3,900 records đại diện cho các giao dịch hoặc hành vi mua sắm của khách hàng. Mỗi record tương ứng với một khách hàng và thông tin liên quan đến đặc điểm nhân khẩu học, hành vi mua hàng và các yếu tố giao dịch.
#
# Tổng cộng dataset gồm 18 variables (columns) bao gồm cả numerical variables và categorical variables.
#
# Theo df.info():
#
# Total observations: 3,900
#
# Total variables: 18
#
# Data types:
#
# Numerical: 4 columns
#
# Categorical (object): 13 columns
#
# Float: 1 column
#
# Memory usage của dataset khá nhỏ (~548 KB), cho thấy dataset có thể xử lý dễ dàng trên các môi trường phân tích thông thường như Python hoặc SQL.
#
# 2. Variables Description
#
# Dataset bao gồm ba nhóm thông tin chính:
#
# 2.1 Customer Demographics
#
# Các biến mô tả đặc điểm của khách hàng:
#
# Variable	Description
# Customer ID	Unique identifier của mỗi khách hàng
# Age	Tuổi khách hàng
# Gender	Giới tính
#
# Những biến này thường được dùng để segment khách hàng theo nhân khẩu học.
#
# 2.2 Purchase Information
#
# Nhóm biến mô tả hành vi mua hàng:
#
# Variable	Description
# Item Purchased	Sản phẩm khách hàng mua
# Category	Loại sản phẩm (Clothing, Footwear...)
# Purchase Amount (USD)	Giá trị đơn hàng
# Size	Kích cỡ sản phẩm
# Color	Màu sản phẩm
# Season	Mùa mua hàng
#
# Những biến này cho phép phân tích:
#
# sản phẩm phổ biến
#
# category performance
#
# purchasing patterns theo mùa
#
# 2.3 Customer Behavior & Transaction Attributes
#
# Các biến mô tả hành vi giao dịch và mức độ tương tác:
#
# Variable	Description
# Review Rating	Rating khách hàng
# Subscription Status	Khách hàng có đăng ký membership
# Shipping Type	Loại vận chuyển
# Discount Applied	Có áp dụng giảm giá
# Promo Code Used	Có sử dụng mã khuyến mãi
# Previous Purchases	Số lần mua trước đó
# Payment Method	Phương thức thanh toán
# Frequency of Purchases	Tần suất mua hàng
#
# Nhóm này giúp phân tích:
#
# customer loyalty
#
# purchase frequency
#
# promotion effectiveness
#
# payment preference
#
# 3. Numerical Variables Summary
#
# Theo df.describe():
#
# Variable	Mean	Min	Max
# Age	~44	18	70
# Purchase Amount	~59 USD	20	100
# Review Rating	~3.75	2.5	5
# Previous Purchases	~25	1	50
# Observations
#
# Age
#
# Khách hàng nằm trong khoảng 18–70 tuổi
#
# Median khoảng 44 tuổi
#
# Cho thấy dataset chủ yếu là adult consumers
#
# Purchase Amount
#
# Trung bình khoảng ~59 USD
#
# Giá trị thấp nhất 20 USD
#
# Cao nhất 100 USD
#
# => Cho thấy dataset chủ yếu đại diện cho low–mid value retail purchases
#
# Review Rating
#
# Mean rating khoảng 3.75 / 5
#
# Phần lớn rating nằm trong khoảng 3.1 – 4.4
#
# => Cho thấy mức độ hài lòng khá tích cực
#
# Previous Purchases
#
# Mean khoảng 25 lần mua
#
# Range từ 1 đến 50
#
# => Dataset có sự kết hợp giữa:
#
# new customers
#
# repeat customers
#
# 4. Data Completeness
#
# Theo df.info():
#
# Hầu hết các biến có 3900 non-null values
#
# Tuy nhiên:
#
# Review Rating
#
# chỉ có 3863 values
#
# => khoảng 37 missing values
#
# Tỷ lệ missing:
#
# 37 / 3900 ≈ 0.95%
#
# => Missing rate <1%, rất thấp và có thể:
#
# drop
#
# hoặc impute

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df = df.rename(columns = {'purchase_amount_(usd)' : 'purchase_amount'})

# %%
 df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
labels = ['Young Adult', 'Adult', 'Middle-aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q = 4, labels = labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged
# 5   46  Middle-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-aged

# %%
#purchase_frequency_days
frequency_mapping = {
    'Fortnightly' : 14,
    'Weekly' : 7,
    'Monthly' : 30,
    'Quarterly' : 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 months': 90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied promo_code_used  previous_purchases  \
# ...

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
df['discount_applied'] == df['promo_code_used'].all()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Name: discount_applied, Length: 3900, dtype: bool

# %%
df['discount_applied'].all() == df['promo_code_used'].all()
# Out:
# np.True_

# %%
df = df.drop('promo_code_used', axis = 1)

# %%
df.to_csv("clean_data.csv", index=False, encoding="utf-8-sig")

from google.colab import files
files.download("clean_data.csv")

# %%
import pandas as pd

df = pd.read_csv('customer_shopping_behavior.csv')
